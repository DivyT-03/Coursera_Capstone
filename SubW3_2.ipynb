# %% [markdown]
# Importing library and requesting data from the wikipedia page

# %%
import urllib.request

# %%
url='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

# %%
page = urllib.request.urlopen(url)

# %% [markdown]
# Importing library for web scrapping

# %%
#!conda install -c conda-forge bs4 --yes
from bs4 import BeautifulSoup

# %% [markdown]
# Getting html code of the requested page

# %%
soup = BeautifulSoup(page, 'html5lib')

# %%
#soup.prettify() Running this code will print the html code where we find the table that we want

# %% [markdown]
# We Observe the table is surrounded by the html table tags th and td

# %%
#soup.title
#soup.title.string Commands to display title of page we requested

# %% [markdown]
# Now we find all tables in the page

# %%
all_tables=soup.find_all("table")
#all_tables Run this command to show the extracted html part of all tables

# %% [markdown]
# We Notice that our table in of class wikitable sortable, so we extract that table

# %%
right_table=soup.find('table', class_='wikitable sortable')
#right_table Run this command to display the table we wanted in html format

# %% [markdown]
# Now we need to extract data from html format. as there are 3 columns we make 3 lists and append values to them. Note each entry starts with th and ends with td.

# %%
A=[]
B=[]
C=[]

for row in right_table.findAll('tr'):
    cells=row.findAll('td')
    if len(cells)==3:
        A.append(cells[0].find(text=True)[:-1:])
        B.append(cells[1].find(text=True)[:-1:])
        C.append(cells[2].find(text=True)[:-1:])

# %% [markdown]
# We convert the lists to dataframe

# %%
import pandas as pd
df=pd.DataFrame(A,columns=['Postal Code'])
df['Borough']=B
df['Neighbourhood']=C

# %%
#df Run this command to display ectire dataframe

# %% [markdown]
# We remove the rows where Borough is "Not assigned"

# %%
df1=df[df['Borough']!='Not assigned']
#df1 Run this command to display the datafarme

# %% [markdown]
# We group the entries on the basis of similar postal code. i.e. same postal code with 2 neighbourhood will become 1 entry(row)

# %%
df2=df1.groupby(['Postal Code','Borough'])['Neighbourhood'].apply(','.join).reset_index()

# %%
#df2 Run to print the dataframe

# %% [markdown]
# We check if there is any Neighbourhood "Not assigned"

# %%
df2[df2['Neighbourhood']=='']
# Out:
# Empty DataFrame
# Columns: [Postal Code, Borough, Neighbourhood]
# Index: []

# %% [markdown]
# As there are no such rows- df2 is our final dataframe. useing .shape to find number of rows

# %%
count=df2.shape

# %%
print("No of rows",count[0])
print("No of columns",count[1])
# Out:
# No of rows 103
# No of columns 3

# %%
#!conda install -c conda-forge geocoder --yes
#!conda install -c conda-forge geopy --yes
import geocoder
from geopy.geocoders import Nominatim #To get latitude and longitide

# %%
latitudelst=[]
longitudelst=[]
x=0
for x,i in enumerate(df2['Neighbourhood']):
    try:
        i=i.split('/')[0]
    finally:
        geolocator=Nominatim(user_agent='foursquare_agent')
        try:
            location=geolocator.geocode(i)
            latitudelst.append(location.latitude)
            longitudelst.append(location.longitude)
        except:
            print(x,i)
            latitudelst.append("Not assigned")
            longitudelst.append("Not assigned")
# Out:
# 45 Davisville North
# 53 Regent Park
# 61 Commerce Court
# 68 CN Tower
# 76 Dufferin
# 83 Parkdale
# 86 Canada Post Gateway Processing Centre
# 87 Business reply mail Processing CentrE
# 91 Old Mill South
# 95 Eringate
# 102 Northwest

# %% [markdown]
# The folloewing Latitude and Longitude wasn't found:
#
# 45 Davisville North;
# 53 Regent Park ;
# 61 Commerce Court;
# 68 CN Tower ;
# 76 Dufferin ;
# 83 Parkdale ;
# 86 Canada Post Gateway Processing Centre;
# 87 Business reply mail Processing CentrE;
# 91 Old Mill South;
# 95 Eringate ;
# 102 Northwest;
#
# So we insert them manually from the given CSV file.

# %%
latitudelst[45]=43.7127511
latitudelst[53]=43.6542599
latitudelst[61]=43.6481985
latitudelst[68]=43.6289467
latitudelst[76]=43.6690051
latitudelst[83]=43.6489597
latitudelst[86]=43.6366956
latitudelst[87]=43.6627439
latitudelst[91]=43.6362579
latitudelst[95]=43.6435152
latitudelst[102]=43.7067483

longitudelst[45]=-79.3901975
longitudelst[53]=-79.3606359
longitudelst[61]=-79.3798169
longitudelst[68]=-79.3944199
longitudelst[76]=-79.4422593
longitudelst[83]=-79.456325
longitudelst[86]=-79.615819
longitudelst[87]=-79.321558
longitudelst[91]=-79.4985091
longitudelst[95]=-79.5772008
longitudelst[102]=-79.5940544

# %%
df2['Latitude']=latitudelst
df2['Longitude']=longitudelst

# %%
df2
# Out:
#     Postal Code           Borough  \
# 0           M1B       Scarborough
# 1           M1C       Scarborough
# 2           M1E       Scarborough
# 3           M1G       Scarborough
# 4           M1H       Scarborough
# 5           M1J       Scarborough
# 6           M1K       Scarborough
# 7           M1L       Scarborough
# 8           M1M       Scarborough
# 9           M1N       Scarborough
# 10          M1P       Scarborough
# 11          M1R       Scarborough
# 12          M1S       Scarborough
# 13          M1T       Scarborough
# 14          M1V       Scarborough
# 15          M1W       Scarborough
# 16          M1X       Scarborough
# 17          M2H        North York
# 18          M2J        North York
# 19          M2K        North York
# 20          M2L        North York
# 21          M2M        North York
# 22          M2N        North York
# 23          M2P        North York
# 24          M2R        North York
# 25          M3A        North York
# 26          M3B        North York
# 27          M3C        North York
# 28          M3H        North York
# 29          M3J        North York
# 30          M3K        North York
# 31          M3L        North York
# 32          M3M        North York
# 33          M3N        North York
# 34          M4A        North York
# 35          M4B         East York
# 36          M4C         East York
# 37          M4E      East Toronto
# 38          M4G         East York
# 39          M4H         East York
# 40          M4J         East York
# 41          M4K      East Toronto
# 42          M4L      East Toronto
# 43          M4M      East Toronto
# 44          M4N   Central Toronto
# 45          M4P   Central Toronto
# 46          M4R   Central Toronto
# 47          M4S   Central Toronto
# 48          M4T   Central Toronto
# 49          M4V   Central Toronto
# 50          M4W  Downtown Toronto
# 51          M4X  Downtown Toronto
# 52          M4Y  Downtown Toronto
# 53          M5A  Downtown Toronto
# 54          M5B  Downtown Toronto
# 55          M5C  Downtown Toronto
# 56          M5E  Downtown Toronto
# 57          M5G  Downtown Toronto
# 58          M5H  Downtown Toronto
# 59          M5J  Downtown Toronto
# 60          M5K  Downtown Toronto
# 61          M5L  Downtown Toronto
# 62          M5M        North York
# 63          M5N   Central Toronto
# 64          M5P   Central Toronto
# 65          M5R   Central Toronto
# 66          M5S  Downtown Toronto
# 67          M5T  Downtown Toronto
# 68          M5V  Downtown Toronto
# 69          M5W  Downtown Toronto
# 70          M5X  Downtown Toronto
# 71          M6A        North York
# 72          M6B        North York
# 73          M6C              York
# 74          M6E              York
# 75          M6G  Downtown Toronto
# 76          M6H      West Toronto
# 77          M6J      West Toronto
# 78          M6K      West Toronto
# 79          M6L        North York
# 80          M6M              York
# 81          M6N              York
# 82          M6P      West Toronto
# 83          M6R      West Toronto
# 84          M6S      West Toronto
# 85          M7A  Downtown Toronto
# 86          M7R       Mississauga
# 87          M7Y      East Toronto
# 88          M8V         Etobicoke
# 89          M8W         Etobicoke
# 90          M8X         Etobicoke
# 91          M8Y         Etobicoke
# 92          M8Z         Etobicoke
# 93          M9A         Etobicoke
# 94          M9B         Etobicoke
# 95          M9C         Etobicoke
# 96          M9L        North York
# 97          M9M        North York
# 98          M9N              York
# 99          M9P         Etobicoke
# 100         M9R         Etobicoke
# 101         M9V         Etobicoke
# 102         M9W         Etobicoke
#
#                                          Neighbourhood   Latitude   Longitude
# 0                                      Malvern / Rouge  52.115956   -2.325899
# 1             Rouge Hill / Port Union / Highland Creek  43.780271  -79.130499
# 2                  Guildwood / Morningside / West Hill  43.755225  -79.198229
# 3                                               Woburn  42.479262  -71.152277
# 4                                            Cedarbrae  50.956318 -114.129323
# 5                                  Scarborough Village  43.743742  -79.211632
# 6        Kennedy Park / Ionview / East Birchmount Park  51.895266   -8.455401
# 7                    Golden Mile / Clairlea / Oakridge  43.727841  -79.287622
# 8    Cliffside / Cliffcrest / Scarborough Village West  43.711170  -79.248177
# 9                         Birch Cliff / Cliffside West  53.846036   -1.777835
# 10   Dorset Park / Wexford Heights / Scarborough To...  43.752847  -79.282067
# 11                                  Wexford / Maryvale  52.460187   -6.606515
# 12                                           Agincourt  48.732347    6.236384
# 13           Clarks Corners / Tam O'Shanter / Sullivan  45.945723  -66.133723
# 14   Milliken / Agincourt North / Steeles East / L'...  43.823174  -79.301763
# 15                      Steeles West / L'Amoreaux West  37.539000  -81.775391
# 16                                         Upper Rouge  42.474616  -83.385668
# 17                                   Hillcrest Village  43.799664  -79.365019
# 18                      Fairview / Henry Farm / Oriole  40.633372  -90.163732
# 19                                     Bayview Village  43.769197  -79.376662
# 20                           York Mills / Silver Hills  43.744039  -79.406657
# 21                            Willowdale / Newtonbrook  43.761510  -79.410923
# 22                                          Willowdale  43.761510  -79.410923
# 23                                     York Mills West  43.744039  -79.406657
# 24                                          Willowdale  43.761510  -79.410923
# 25                                           Parkwoods  37.856774 -122.220688
# 26                                           Don Mills  43.775347  -79.345944
# 27                                           Don Mills  43.775347  -79.345944
# 28   Bathurst Manor / Wilson Heights / Downsview North -33.416638  149.580494
# 29                    Northwood Park / York University  43.754135  -79.504480
# 30                                           Downsview  43.749299  -79.462248
# 31                                           Downsview  43.749299  -79.462248
# 32                                           Downsview  43.749299  -79.462248
# 33                                           Downsview  43.749299  -79.462248
# 34                                    Victoria Village  43.732658  -79.311189
# 35                    Parkview Hill / Woodbine Gardens  41.021916 -106.398361
# 36                                    Woodbine Heights  43.699930  -79.319132
# 37                                         The Beaches  43.671024  -79.296712
# 38                                             Leaside  43.704798  -79.368090
# 39                                    Thorncliffe Park  43.704553  -79.345407
# 40                                        East Toronto  43.653482  -79.383935
# 41                       The Danforth West / Riverdale  40.820312  -87.977818
# 42                     India Bazaar / The Beaches West  42.701847  -73.814190
# 43                                     Studio District -12.271035   49.291897
# 44                                       Lawrence Park  42.152279  -80.023112
# 45                                    Davisville North  43.712751  -79.390197
# 46                                  North Toronto West  43.646547  -79.419526
# 47                                          Davisville  43.697936  -79.397291
# 48                        Moore Park / Summerhill East -33.895833  151.221944
# 49   Summerhill West / Rathnelly / South Hill / For...  43.681678  -79.390504
# 50                                            Rosedale  35.377724 -119.145659
# 51                        St. James Town / Cabbagetown  43.669403  -79.372704
# 52                                Church and Wellesley  43.665524  -79.383801
# 53                          Regent Park / Harbourfront  43.654260  -79.360636
# 54                            Garden District, Ryerson  48.478380  -84.710869
# 55                                      St. James Town  43.669403  -79.372704
# 56                                         Berczy Park  43.647984  -79.375396
# 57                                  Central Bay Street  40.808189  -74.208741
# 58                          Richmond / Adelaide / King  37.538509  -77.434280
# 59   Harbourfront East / Union Station / Toronto Is...   1.265395  103.822403
# 60           Toronto Dominion Centre / Design Exchange  43.647377  -79.381372
# 61                     Commerce Court / Victoria Hotel  43.648198  -79.379817
# 62                  Bedford Park / Lawrence Manor East  41.762810  -87.800055
# 63                                            Roselawn  41.151458  -87.285675
# 64                            Forest Hill North & West  42.079241  -77.001077
# 65               The Annex / North Midtown / Yorkville  43.670338  -79.407117
# 66                     University of Toronto / Harbord  43.663462  -79.397760
# 67         Kensington Market / Chinatown / Grange Park  43.655214  -79.402260
# 68   CN Tower / King and Spadina / Railway Lands / ...  43.628947  -79.394420
# 69                                      Stn A PO Boxes  33.861120 -118.143858
# 70             First Canadian Place / Underground city  43.648768  -79.381692
# 71                   Lawrence Manor / Lawrence Heights  43.722079  -79.437507
# 72                                           Glencairn  43.708712  -79.440685
# 73                                  Humewood-Cedarvale  43.690844  -79.424931
# 74                                 Caledonia-Fairbanks  44.420060  -72.019779
# 75                                            Christie  43.664111  -79.418405
# 76                       Dufferin / Dovercourt Village  43.669005  -79.442259
# 77                           Little Portugal / Trinity  43.647413  -79.431116
# 78      Brockton / Parkdale Village / Exhibition Place  42.083433  -71.018379
# 79          North Park / Maple Leaf Park / Upwood Park  32.748388 -117.130156
# 80   Del Ray / Mount Dennis / Keelsdale and Silvert...  38.821227  -77.062758
# 81                      Runnymede / The Junction North  51.394837   -0.551961
# 82                      High Park / The Junction South  43.653867  -79.466864
# 83                             Parkdale / Roncesvalles  43.648960  -79.456325
# 84                                 Runnymede / Swansea  51.394837   -0.551961
# 85        Queen's Park / Ontario Provincial Government  43.659659  -79.390340
# 86               Canada Post Gateway Processing Centre  43.636696  -79.615819
# 87               Business reply mail Processing CentrE  43.662744  -79.321558
# 88      New Toronto / Mimico South / Humber Bay Shores  43.600763  -79.505264
# 89                             Alderwood / Long Branch  43.601717  -79.545232
# 90    The Kingsway / Montgomery Road  / Old Mill North  43.647381  -79.511333
# 91   Old Mill South / King's Mill Park / Sunnylea /...  43.636258  -79.498509
# 92   Mimico NW / The Queensway West / South of Bloo...  39.118377  -76.609209
# 93                                    Islington Avenue  43.786905  -79.588878
# 94   West Deane Park / Princess Gardens / Martin Gr...  43.663199  -79.568568
# 95   Eringate / Bloordale Gardens / Old Burnhamthor...  43.643515  -79.577201
# 96                                       Humber Summit  43.760078  -79.571760
# 97                                   Humberlea / Emery  43.721317  -79.533160
# 98                                              Weston  51.347193   -2.977892
# 99                                           Westmount  45.485733  -73.596395
# 100  Kingsview Village / St. Phillips / Martin Grov...  43.699539  -79.556346
# 101  South Steeles / Silverstone / Humbergate / Jam...  43.816178  -79.314538
# 102                                          Northwest  43.706748  -79.594054
